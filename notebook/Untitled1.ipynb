# %%
import pandas as pd
import datetime as dt
import re as re
import numpy as np

# %%
ddid = pd.read_excel(r"C:\Users\emmaj\Documents\NSS\Python\Projects\ddid-rasberry-pi\data\TEIS Exit Data for NSS.xlsx", sheet_name = 3)
pd.set_option('display.max_colwidth', None)
ddid.head()
# Out:
#   POE  Child ID        DOB Notification Date Initial Eligibility Date  \
# 0  UC    471738 2019-02-28        2019-10-17               2019-10-29
# 1  FT    449030 2018-07-22        2018-11-07               2018-12-03
# 2  FT    463311 2017-07-09        2019-05-24               2019-06-19
# 3  FT    463313 2017-07-09        2019-05-24               2019-06-19
# 4  FT    469194 2017-08-31        2019-09-04               2019-10-02
#
#   Initial IFSP Date Latest IFSP Date                              Exit Reason  \
# 0        2019-10-31       2020-05-12                    618 - Parent withdraw
# 1        2018-12-18       2021-03-04                 618 - Moved out of state
# 2        2019-07-02       2020-06-22  618 - Part B eligibility not determined
# 3        2019-07-02       2020-06-22  618 - Part B eligibility not determined
# 4        2019-10-11       2020-05-26  618 - Part B eligibility not determined
#
#    Exit Date  Days from I-IFSP to Exit  \
# ...

# %%
ddid = pd.DataFrame(ddid)
pd.set_option('display.max_colwidth', None)
ddid.head()

ddid_mvp = ddid[['Child ID', 'DOB', 'Initial IFSP Date', 'Exit Date', 'Exit Reason', 'Exit Note']]

ddid_mvp_filtered = ddid_mvp[ddid_mvp['Exit Note'].notnull()]
pd.set_option('display.max_colwidth', None)
ddid_mvp_filtered.tail()
# Out:
#       Child ID        DOB Initial IFSP Date  Exit Date  \
# 2246    463962 2017-07-02        2019-07-10 2020-07-01
# 2247    454305 2017-07-06        2019-03-08 2020-07-02
# 2248    450369 2017-08-16        2018-12-19 2020-08-15
# 2249    476783 2017-11-24        2020-03-04 2020-11-23
# 2250    486852 2020-04-10        2020-09-09 2021-04-16
#
#                                                 Exit Reason  \
# 2246                618 - Part B eligibility not determined
# 2247  618 - Completion of IFSP/ no longer requires services
# 2248                618 - Part B eligibility not determined
# 2249                618 - Part B eligibility not determined
# 2250                 618 - Attempts to contact unsuccessful
#
#                                                                                                                Exit Note
# 2246                                               Transition meeting late due to COVID-19 Pandemic and School closings.
# ...

# %%
ddid_mvp_filtered.loc[ddid_mvp_filtered['Exit Note'].str.contains('reopen[a-z]*', flags=re.I, regex=True)]
# Out:
#       Child ID        DOB Initial IFSP Date  Exit Date  \
# 5       473474 2017-11-05        2020-05-06 2020-11-04
# 8       469243 2019-07-26        2019-10-02 2021-02-11
# 12      436339 2018-04-05        2019-02-13 2021-04-01
# 16      474102 2018-05-11        2020-04-09 2021-05-10
# 21      476958 2018-10-17        2020-08-24 2021-05-25
# ...        ...        ...               ...        ...
# 2223    469136 2017-10-24        2019-10-23 2020-10-23
# 2227    432033 2017-12-30        2018-04-25 2020-12-29
# 2232    469330 2018-02-18        2020-05-13 2021-02-18
# 2233    428532 2017-07-13        2018-01-26 2020-07-12
# 2243    463610 2017-08-09        2019-08-12 2020-08-08
#
#                                   Exit Reason  \
# 5     618 - Part B eligibility not determined
# 8                       618 - Parent withdraw
# 12    618 - Part B eligibility not determined
# 16    618 - Part B eligibility not determined
# 21                      618 - Parent withdraw
# ...

# %%
ddid_mvp_filtered['Exit Note'].str.findall(r'/')
# Out:
# 0           []
# 1           []
# 2           []
# 3           []
# 4           []
#          ...
# 2246        []
# 2247        []
# 2248    [/, /]
# 2249        []
# 2250    [/, /]
# Name: Exit Note, Length: 2251, dtype: object

# %%
dates = ddid_mvp_filtered['Exit Note'].str.findall(r'\d{2}/\d{2}')
dates.head(25)
# Out:
# 0                                                                                []
# 1                                                                                []
# 2                                                                                []
# 3                                                                                []
# 4                                                                                []
# 5                                                                    [04/06, 11/26]
# 6                                                                                []
# 7                                                                           [01/19]
# 8                                                                    [02/05, 04/07]
# 9                                                                           [03/19]
# 10                                                                          [03/31]
# ...

# %%
# Out:
# 0       []
# 1       []
# 2       []
# 3       []
# 4       []
#         ..
# 2246    []
# 2247    []
# 2248    []
# 2249    []
# 2250    []
# Name: Exit Note, Length: 2251, dtype: object
