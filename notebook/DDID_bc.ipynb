# %%
import pandas as pd
import re
import datetime as dt
import numpy as np

# %%
# read 2nd sheet of an excel file
ddid = pd.read_excel(r"/Users/brentcleland/NSS/Projects/ddid-rasberry-pi/data/TEIS Exit Data for NSS.xlsx", sheet_name =3)

# %%
ddid[['Child ID', 'DOB', 'Initial IFSP Date', 'Exit Date', 'Exit Reason', 'Exit Note']]
# Out:
#       Child ID        DOB Initial IFSP Date  Exit Date  \
# 0       471738 2019-02-28        2019-10-31 2020-09-21
# 1       449030 2018-07-22        2018-12-18 2021-03-06
# 2       463311 2017-07-09        2019-07-02 2020-07-08
# 3       463313 2017-07-09        2019-07-02 2020-07-08
# 4       469194 2017-08-31        2019-10-11 2020-08-30
# ...        ...        ...               ...        ...
# 5577    491609 2018-12-22        2020-11-09 2021-05-17
# 5578    491743 2018-06-05        2020-11-09 2021-06-04
# 5579    491879 2019-04-24        2020-11-04 2021-05-06
# 5580    492267 2018-06-01        2020-11-24 2021-05-31
# 5581    492408 2020-08-06        2020-11-20 2021-05-20
#
#                                   Exit Reason  \
# 0                       618 - Parent withdraw
# 1                    618 - Moved out of state
# 2     618 - Part B eligibility not determined
# 3     618 - Part B eligibility not determined
# 4     618 - Part B eligibility not determined
# ...                                       ...
# 5577   618 - Attempts to contact unsuccessful
# 5578  618 - Part B eligibility not determined
# 5579                    618 - Parent withdraw
# 5580  618 - Part B eligibility not determined
# 5581   618 - Attempts to contact unsuccessful
#
#                                               Exit Note
# 0               * No Exit ECO available due to COVID-19
# 1     ***family moving out of state March 2021, and ...
# 2     **Completed the transition planning conference...
# 3     **Completed the transition planning conference...
# 4     **Due to the impact of the COVID-19 pandemic a...
# ...                                                 ...
# 5577                                                NaN
# 5578                                                NaN
# 5579                                                NaN
# 5580                                                NaN
# 5581                                                NaN
#
# [5582 rows x 6 columns]

# %%
ddid_filtered = ddid[ddid['Exit Note'].notnull()]
ddid_filtered.head()
# Out:
#   POE  Child ID        DOB Notification Date Initial Eligibility Date  \
# 0  UC    471738 2019-02-28        2019-10-17               2019-10-29
# 1  FT    449030 2018-07-22        2018-11-07               2018-12-03
# 2  FT    463311 2017-07-09        2019-05-24               2019-06-19
# 3  FT    463313 2017-07-09        2019-05-24               2019-06-19
# 4  FT    469194 2017-08-31        2019-09-04               2019-10-02
#
#   Initial IFSP Date Latest IFSP Date                              Exit Reason  \
# 0        2019-10-31       2020-05-12                    618 - Parent withdraw
# 1        2018-12-18       2021-03-04                 618 - Moved out of state
# 2        2019-07-02       2020-06-22  618 - Part B eligibility not determined
# 3        2019-07-02       2020-06-22  618 - Part B eligibility not determined
# 4        2019-10-11       2020-05-26  618 - Part B eligibility not determined
#
#    Exit Date  Days from I-IFSP to Exit  \
# 0 2020-09-21                       326
# 1 2021-03-06                       809
# 2 2020-07-08                       372
# 3 2020-07-08                       372
# 4 2020-08-30                       324
#
#                                            Exit Note
# 0            * No Exit ECO available due to COVID-19
# 1  ***family moving out of state March 2021, and ...
# 2  **Completed the transition planning conference...
# 3  **Completed the transition planning conference...
# 4  **Due to the impact of the COVID-19 pandemic a...

# %%
#ddid_filtered['Exit Note']

# %%
#ddid_filtered.loc[ddid_filtered['Exit Note'].str.contains(r"(\d+/\d+/\d+)", case=False)]

# %%
#search.to_csv('new_filter.csv')

# %%
search = ddid_filtered.loc[ddid_filtered['Exit Note'].str.contains('(Reopened:)\s\d{2}/\d{2}/\d{4}\s(Exit Date:)\s\d{2}/\d{2}/\d{4}')]
search
# Out:
# /Users/brentcleland/opt/anaconda3/lib/python3.8/site-packages/pandas/core/strings/accessor.py:101: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)
#      POE  Child ID        DOB Notification Date Initial Eligibility Date  \
# 5     UC    473474 2017-11-05        2020-04-06               2020-04-24
# 8     GN    469243 2019-07-26        2019-09-04               2019-10-01
# 12    SE    436339 2018-04-05        2019-01-11               2019-01-31
# 16    ET    474102 2018-05-11        2020-02-27               2020-03-12
# 21    GN    476958 2018-10-17        2020-08-04               2020-08-18
# ...   ..       ...        ...               ...                      ...
# 2223  ET    469136 2017-10-24        2019-09-04               2019-10-03
# 2227  SC    432033 2017-12-30        2018-03-13               2018-04-24
# 2232  ET    469330 2018-02-18        2020-03-05               2020-05-07
# 2233  SE    428532 2017-07-13        2018-01-04               2018-01-16
# 2243  ET    463610 2017-08-09        2019-07-18               2019-07-29
#
#      Initial IFSP Date Latest IFSP Date  \
# 5           2020-05-06       2020-06-23
# 8           2019-10-02       2020-03-19
# 12          2019-02-13       2021-01-29
# 16          2020-04-09       2021-03-29
# 21          2020-08-24       2021-02-12
# ...                ...              ...
# 2223        2019-10-23       2020-10-01
# 2227        2018-04-25       2020-10-19
# 2232        2020-05-13       2020-12-01
# 2233        2018-01-26       2020-04-01
# 2243        2019-08-12       2020-05-12
#
#                                   Exit Reason  Exit Date  \
# 5     618 - Part B eligibility not determined 2020-11-04
# 8                       618 - Parent withdraw 2021-02-11
# 12    618 - Part B eligibility not determined 2021-04-01
# 16    618 - Part B eligibility not determined 2021-05-10
# 21                      618 - Parent withdraw 2021-05-25
# ...                                       ...        ...
# 2223  618 - Part B eligibility not determined 2020-10-23
# 2227                    618 - Part B eligible 2020-12-29
# 2232                    618 - Part B eligible 2021-02-18
# 2233  618 - Part B eligibility not determined 2020-07-12
# 2243   618 - Attempts to contact unsuccessful 2020-08-08
#
#       Days from I-IFSP to Exit  \
# 5                          182
# 8                          498
# 12                         778
# 16                         396
# 21                         274
# ...                        ...
# 2223                       366
# 2227                       979
# 2232                       281
# 2233                       898
# 2243                       362
#
#                                               Exit Note
# 5     **LEA county on the Transition page and demogr...
# 8     02-11-2021 – PWN signed and returned for volun...
# 12    04/01/2021- File closed business day prior to ...
# 16    05/10/2021 TPC held then parents withdrew from...
# 21    05/25/21- parent withdraw Reopened: 08/04/2020...
# ...                                                 ...
# 2223  The family ended TEIS services, and requested ...
# 2227  The TPC was late due to LEA getting COVID and ...
# 2232  TPC 10/19/2020 Reopened: 03/05/2020 Exit Date:...
# 2233  TPC held and further assessments agreed to; PA...
# 2243  TPC was late due to SC's inability to get a re...
#
# [1691 rows x 11 columns]

# %%
search['Exit Note'].str.extract(r'(Reopened:\d{2}/\d{2}/\d{4})')
search.head(2)
# Out:
#   POE  Child ID        DOB Notification Date Initial Eligibility Date  \
# 5  UC    473474 2017-11-05        2020-04-06               2020-04-24
# 8  GN    469243 2019-07-26        2019-09-04               2019-10-01
#
#   Initial IFSP Date Latest IFSP Date                              Exit Reason  \
# 5        2020-05-06       2020-06-23  618 - Part B eligibility not determined
# 8        2019-10-02       2020-03-19                    618 - Parent withdraw
#
#    Exit Date  Days from I-IFSP to Exit  \
# 5 2020-11-04                       182
# 8 2021-02-11                       498
#
#                                            Exit Note
# 5  **LEA county on the Transition page and demogr...
# 8  02-11-2021 – PWN signed and returned for volun...

# %% [markdown]
# Findall messed up the str function below we used extract

# %%
#search['Exit Note'].str.findall(r'Reopened:\d{2}/\d{2}/\d{4}')
#search.head(2)

# %%
dates = search['Exit Note'].str.extract(r'(Reopened: \d{2}/\d{2}/\d{4}) (Exit Date: \d{2}/\d{2}/\d{4})')
dates
# Out:
#                          0                      1
# 5     Reopened: 04/06/2020  Exit Date: 11/26/2019
# 8     Reopened: 02/05/2021  Exit Date: 04/07/2020
# 12    Reopened: 01/11/2019  Exit Date: 06/17/2018
# 16    Reopened: 02/28/2020  Exit Date: 12/05/2019
# 21    Reopened: 08/04/2020  Exit Date: 03/09/2020
# ...                    ...                    ...
# 2223  Reopened: 07/28/2020  Exit Date: 04/26/2020
# 2227  Reopened: 02/05/2019  Exit Date: 10/23/2018
# 2232  Reopened: 03/05/2020  Exit Date: 09/17/2019
# 2233  Reopened: 10/25/2018  Exit Date: 05/24/2018
# 2243  Reopened: 07/19/2019  Exit Date: 06/25/2019
#
# [1691 rows x 2 columns]

# %%
#dates = search['Exit Note'].str.findall(r'(Reopened: \d{2}/\d{2}/\d{4}) (Exit Date: \d{2}/\d{2}/\d{4})')
#dates

# %%
reopen_adjusted = search['Exit Note'].str.extract(r'(Reopened: \d{2}/\d{2}/\d{4})')
reopen_adjusted
# Out:
#                          0
# 5     Reopened: 04/06/2020
# 8     Reopened: 02/05/2021
# 12    Reopened: 01/11/2019
# 16    Reopened: 02/28/2020
# 21    Reopened: 08/04/2020
# ...                    ...
# 2223  Reopened: 07/28/2020
# 2227  Reopened: 02/05/2019
# 2232  Reopened: 03/05/2020
# 2233  Reopened: 10/25/2018
# 2243  Reopened: 07/19/2019
#
# [1691 rows x 1 columns]

# %%
#reopen_adjusted = search['Exit Note'].str.findall(r'(Reopened: \d{2}/\d{2}/\d{4})')
#reopen_adjusted

# %%
exit_adjusted  = search['Exit Note'].str.extract(r'(Exit Date: \d{2}/\d{2}/\d{4})')
exit_adjusted
# Out:
#                           0
# 5     Exit Date: 11/26/2019
# 8     Exit Date: 04/07/2020
# 12    Exit Date: 06/17/2018
# 16    Exit Date: 12/05/2019
# 21    Exit Date: 03/09/2020
# ...                     ...
# 2223  Exit Date: 04/26/2020
# 2227  Exit Date: 10/23/2018
# 2232  Exit Date: 09/17/2019
# 2233  Exit Date: 05/24/2018
# 2243  Exit Date: 06/25/2019
#
# [1691 rows x 1 columns]

# %%
#exit_adjusted  =search['Exit Note'].str.findall(r'(Exit Date: \d{2}/\d{2}/\d{4})')
#exit_adjusted

# %%
#exit_adjusted1=search['Exit Note'].str.findall(r'\d{2}/\d{2}/\d{4}')
#exit_adjusted1

# %%
search['reopen_date'] = reopen_adjusted
search.head()
# Out:
# <ipython-input-18-af3721c21b5e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   search['reopen_date'] = reopen_adjusted
#    POE  Child ID        DOB Notification Date Initial Eligibility Date  \
# 5   UC    473474 2017-11-05        2020-04-06               2020-04-24
# 8   GN    469243 2019-07-26        2019-09-04               2019-10-01
# 12  SE    436339 2018-04-05        2019-01-11               2019-01-31
# 16  ET    474102 2018-05-11        2020-02-27               2020-03-12
# 21  GN    476958 2018-10-17        2020-08-04               2020-08-18
#
#    Initial IFSP Date Latest IFSP Date  \
# 5         2020-05-06       2020-06-23
# 8         2019-10-02       2020-03-19
# 12        2019-02-13       2021-01-29
# 16        2020-04-09       2021-03-29
# 21        2020-08-24       2021-02-12
#
#                                 Exit Reason  Exit Date  \
# 5   618 - Part B eligibility not determined 2020-11-04
# 8                     618 - Parent withdraw 2021-02-11
# 12  618 - Part B eligibility not determined 2021-04-01
# 16  618 - Part B eligibility not determined 2021-05-10
# 21                    618 - Parent withdraw 2021-05-25
#
#     Days from I-IFSP to Exit  \
# 5                        182
# 8                        498
# 12                       778
# 16                       396
# 21                       274
#
#                                             Exit Note           reopen_date
# 5   **LEA county on the Transition page and demogr...  Reopened: 04/06/2020
# 8   02-11-2021 – PWN signed and returned for volun...  Reopened: 02/05/2021
# 12  04/01/2021- File closed business day prior to ...  Reopened: 01/11/2019
# 16  05/10/2021 TPC held then parents withdrew from...  Reopened: 02/28/2020
# 21  05/25/21- parent withdraw Reopened: 08/04/2020...  Reopened: 08/04/2020

# %%
search['exit_date_adjusted'] = exit_adjusted
search.head()
# Out:
# <ipython-input-19-060a63fe7047>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   search['exit_date_adjusted'] = exit_adjusted
#    POE  Child ID        DOB Notification Date Initial Eligibility Date  \
# 5   UC    473474 2017-11-05        2020-04-06               2020-04-24
# 8   GN    469243 2019-07-26        2019-09-04               2019-10-01
# 12  SE    436339 2018-04-05        2019-01-11               2019-01-31
# 16  ET    474102 2018-05-11        2020-02-27               2020-03-12
# 21  GN    476958 2018-10-17        2020-08-04               2020-08-18
#
#    Initial IFSP Date Latest IFSP Date  \
# 5         2020-05-06       2020-06-23
# 8         2019-10-02       2020-03-19
# 12        2019-02-13       2021-01-29
# 16        2020-04-09       2021-03-29
# 21        2020-08-24       2021-02-12
#
#                                 Exit Reason  Exit Date  \
# 5   618 - Part B eligibility not determined 2020-11-04
# 8                     618 - Parent withdraw 2021-02-11
# 12  618 - Part B eligibility not determined 2021-04-01
# 16  618 - Part B eligibility not determined 2021-05-10
# 21                    618 - Parent withdraw 2021-05-25
#
#     Days from I-IFSP to Exit  \
# 5                        182
# 8                        498
# 12                       778
# 16                       396
# 21                       274
#
#                                             Exit Note           reopen_date  \
# 5   **LEA county on the Transition page and demogr...  Reopened: 04/06/2020
# 8   02-11-2021 – PWN signed and returned for volun...  Reopened: 02/05/2021
# 12  04/01/2021- File closed business day prior to ...  Reopened: 01/11/2019
# 16  05/10/2021 TPC held then parents withdrew from...  Reopened: 02/28/2020
# 21  05/25/21- parent withdraw Reopened: 08/04/2020...  Reopened: 08/04/2020
#
#        exit_date_adjusted
# 5   Exit Date: 11/26/2019
# 8   Exit Date: 04/07/2020
# 12  Exit Date: 06/17/2018
# 16  Exit Date: 12/05/2019
# 21  Exit Date: 03/09/2020

# %%
#search['exit_date_adjusted'] = search['exit_date_adjusted'].str.extract('(\d+.\d+.\d+)')
#search

# %%
exit_val = search['exit_date_adjusted'].str.extract('(\d+.\d+.\d+)')
exit_val
# Out:
#                0
# 5     11/26/2019
# 8     04/07/2020
# 12    06/17/2018
# 16    12/05/2019
# 21    03/09/2020
# ...          ...
# 2223  04/26/2020
# 2227  10/23/2018
# 2232  09/17/2019
# 2233  05/24/2018
# 2243  06/25/2019
#
# [1691 rows x 1 columns]

# %%
#exit_val = search['exit_date_adjusted'].astype(str).str.extract('(\d+.\d+.\d+\ Exit Reason: 618)')
#exit_val.to_csv('x.csv')

# %%
reopen_val = search['reopen_date'].astype(str).str.extract('(\d+.\d+.\d+)')

# %%
search['reopen_date'] = reopen_val
search
# Out:
# <ipython-input-24-6dc4b736cda0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   search['reopen_date'] = reopen_val
#      POE  Child ID        DOB Notification Date Initial Eligibility Date  \
# 5     UC    473474 2017-11-05        2020-04-06               2020-04-24
# 8     GN    469243 2019-07-26        2019-09-04               2019-10-01
# 12    SE    436339 2018-04-05        2019-01-11               2019-01-31
# 16    ET    474102 2018-05-11        2020-02-27               2020-03-12
# 21    GN    476958 2018-10-17        2020-08-04               2020-08-18
# ...   ..       ...        ...               ...                      ...
# 2223  ET    469136 2017-10-24        2019-09-04               2019-10-03
# 2227  SC    432033 2017-12-30        2018-03-13               2018-04-24
# 2232  ET    469330 2018-02-18        2020-03-05               2020-05-07
# 2233  SE    428532 2017-07-13        2018-01-04               2018-01-16
# 2243  ET    463610 2017-08-09        2019-07-18               2019-07-29
#
#      Initial IFSP Date Latest IFSP Date  \
# 5           2020-05-06       2020-06-23
# 8           2019-10-02       2020-03-19
# 12          2019-02-13       2021-01-29
# 16          2020-04-09       2021-03-29
# 21          2020-08-24       2021-02-12
# ...                ...              ...
# 2223        2019-10-23       2020-10-01
# 2227        2018-04-25       2020-10-19
# 2232        2020-05-13       2020-12-01
# 2233        2018-01-26       2020-04-01
# 2243        2019-08-12       2020-05-12
#
#                                   Exit Reason  Exit Date  \
# 5     618 - Part B eligibility not determined 2020-11-04
# 8                       618 - Parent withdraw 2021-02-11
# 12    618 - Part B eligibility not determined 2021-04-01
# 16    618 - Part B eligibility not determined 2021-05-10
# 21                      618 - Parent withdraw 2021-05-25
# ...                                       ...        ...
# 2223  618 - Part B eligibility not determined 2020-10-23
# 2227                    618 - Part B eligible 2020-12-29
# 2232                    618 - Part B eligible 2021-02-18
# 2233  618 - Part B eligibility not determined 2020-07-12
# 2243   618 - Attempts to contact unsuccessful 2020-08-08
#
#       Days from I-IFSP to Exit  \
# 5                          182
# 8                          498
# 12                         778
# 16                         396
# 21                         274
# ...                        ...
# 2223                       366
# 2227                       979
# 2232                       281
# 2233                       898
# 2243                       362
#
#                                               Exit Note reopen_date  \
# 5     **LEA county on the Transition page and demogr...  04/06/2020
# 8     02-11-2021 – PWN signed and returned for volun...  02/05/2021
# 12    04/01/2021- File closed business day prior to ...  01/11/2019
# 16    05/10/2021 TPC held then parents withdrew from...  02/28/2020
# 21    05/25/21- parent withdraw Reopened: 08/04/2020...  08/04/2020
# ...                                                 ...         ...
# 2223  The family ended TEIS services, and requested ...  07/28/2020
# 2227  The TPC was late due to LEA getting COVID and ...  02/05/2019
# 2232  TPC 10/19/2020 Reopened: 03/05/2020 Exit Date:...  03/05/2020
# 2233  TPC held and further assessments agreed to; PA...  10/25/2018
# 2243  TPC was late due to SC's inability to get a re...  07/19/2019
#
#          exit_date_adjusted
# 5     Exit Date: 11/26/2019
# 8     Exit Date: 04/07/2020
# 12    Exit Date: 06/17/2018
# 16    Exit Date: 12/05/2019
# 21    Exit Date: 03/09/2020
# ...                     ...
# 2223  Exit Date: 04/26/2020
# 2227  Exit Date: 10/23/2018
# 2232  Exit Date: 09/17/2019
# 2233  Exit Date: 05/24/2018
# 2243  Exit Date: 06/25/2019
#
# [1691 rows x 13 columns]

# %%
search['exit_date_adjusted'] = exit_val
search.head()
# Out:
# <ipython-input-25-3777a8314f5a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   search['exit_date_adjusted'] = exit_val
#    POE  Child ID        DOB Notification Date Initial Eligibility Date  \
# 5   UC    473474 2017-11-05        2020-04-06               2020-04-24
# 8   GN    469243 2019-07-26        2019-09-04               2019-10-01
# 12  SE    436339 2018-04-05        2019-01-11               2019-01-31
# 16  ET    474102 2018-05-11        2020-02-27               2020-03-12
# 21  GN    476958 2018-10-17        2020-08-04               2020-08-18
#
#    Initial IFSP Date Latest IFSP Date  \
# 5         2020-05-06       2020-06-23
# 8         2019-10-02       2020-03-19
# 12        2019-02-13       2021-01-29
# 16        2020-04-09       2021-03-29
# 21        2020-08-24       2021-02-12
#
#                                 Exit Reason  Exit Date  \
# 5   618 - Part B eligibility not determined 2020-11-04
# 8                     618 - Parent withdraw 2021-02-11
# 12  618 - Part B eligibility not determined 2021-04-01
# 16  618 - Part B eligibility not determined 2021-05-10
# 21                    618 - Parent withdraw 2021-05-25
#
#     Days from I-IFSP to Exit  \
# 5                        182
# 8                        498
# 12                       778
# 16                       396
# 21                       274
#
#                                             Exit Note reopen_date  \
# 5   **LEA county on the Transition page and demogr...  04/06/2020
# 8   02-11-2021 – PWN signed and returned for volun...  02/05/2021
# 12  04/01/2021- File closed business day prior to ...  01/11/2019
# 16  05/10/2021 TPC held then parents withdrew from...  02/28/2020
# 21  05/25/21- parent withdraw Reopened: 08/04/2020...  08/04/2020
#
#    exit_date_adjusted
# 5          11/26/2019
# 8          04/07/2020
# 12         06/17/2018
# 16         12/05/2019
# 21         03/09/2020

# %%
display(search.dtypes)
# Out:
# POE                                 object
# Child ID                             int64
# DOB                         datetime64[ns]
# Notification Date           datetime64[ns]
# Initial Eligibility Date    datetime64[ns]
# Initial IFSP Date           datetime64[ns]
# Latest IFSP Date            datetime64[ns]
# Exit Reason                         object
# Exit Date                   datetime64[ns]
# Days from I-IFSP to Exit             int64
# Exit Note                           object
# reopen_date                         object
# exit_date_adjusted                  object
# dtype: object

# %%
#pd.to_datetime(df['your_time_column'])
pd.to_datetime(search['reopen_date'])
# Out:
# 5      2020-04-06
# 8      2021-02-05
# 12     2019-01-11
# 16     2020-02-28
# 21     2020-08-04
#           ...
# 2223   2020-07-28
# 2227   2019-02-05
# 2232   2020-03-05
# 2233   2018-10-25
# 2243   2019-07-19
# Name: reopen_date, Length: 1691, dtype: datetime64[ns]

# %%
#pd.to_datetime(df['your_time_column'])
pd.to_datetime(search['exit_date_adjusted'])
# Out:
# 5      2019-11-26
# 8      2020-04-07
# 12     2018-06-17
# 16     2019-12-05
# 21     2020-03-09
#           ...
# 2223   2020-04-26
# 2227   2018-10-23
# 2232   2019-09-17
# 2233   2018-05-24
# 2243   2019-06-25
# Name: exit_date_adjusted, Length: 1691, dtype: datetime64[ns]

# %%
search['reopen_date'] = pd.to_datetime(search['reopen_date'])
# Out:
# <ipython-input-29-1c6242d01e69>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   search['reopen_date'] = pd.to_datetime(search['reopen_date'])

# %%
search['exit_date_adjusted'] = pd.to_datetime(search['exit_date_adjusted'])

#df['date_column'] = pd.to_datetime(df['datetime_column']).dt.date
# Out:
# <ipython-input-30-1253688dc6e2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   search['exit_date_adjusted'] = pd.to_datetime(search['exit_date_adjusted'])

# %%
search
# Out:
#      POE  Child ID        DOB Notification Date Initial Eligibility Date  \
# 5     UC    473474 2017-11-05        2020-04-06               2020-04-24
# 8     GN    469243 2019-07-26        2019-09-04               2019-10-01
# 12    SE    436339 2018-04-05        2019-01-11               2019-01-31
# 16    ET    474102 2018-05-11        2020-02-27               2020-03-12
# 21    GN    476958 2018-10-17        2020-08-04               2020-08-18
# ...   ..       ...        ...               ...                      ...
# 2223  ET    469136 2017-10-24        2019-09-04               2019-10-03
# 2227  SC    432033 2017-12-30        2018-03-13               2018-04-24
# 2232  ET    469330 2018-02-18        2020-03-05               2020-05-07
# 2233  SE    428532 2017-07-13        2018-01-04               2018-01-16
# 2243  ET    463610 2017-08-09        2019-07-18               2019-07-29
#
#      Initial IFSP Date Latest IFSP Date  \
# 5           2020-05-06       2020-06-23
# 8           2019-10-02       2020-03-19
# 12          2019-02-13       2021-01-29
# 16          2020-04-09       2021-03-29
# 21          2020-08-24       2021-02-12
# ...                ...              ...
# 2223        2019-10-23       2020-10-01
# 2227        2018-04-25       2020-10-19
# 2232        2020-05-13       2020-12-01
# 2233        2018-01-26       2020-04-01
# 2243        2019-08-12       2020-05-12
#
#                                   Exit Reason  Exit Date  \
# 5     618 - Part B eligibility not determined 2020-11-04
# 8                       618 - Parent withdraw 2021-02-11
# 12    618 - Part B eligibility not determined 2021-04-01
# 16    618 - Part B eligibility not determined 2021-05-10
# 21                      618 - Parent withdraw 2021-05-25
# ...                                       ...        ...
# 2223  618 - Part B eligibility not determined 2020-10-23
# 2227                    618 - Part B eligible 2020-12-29
# 2232                    618 - Part B eligible 2021-02-18
# 2233  618 - Part B eligibility not determined 2020-07-12
# 2243   618 - Attempts to contact unsuccessful 2020-08-08
#
#       Days from I-IFSP to Exit  \
# 5                          182
# 8                          498
# 12                         778
# 16                         396
# 21                         274
# ...                        ...
# 2223                       366
# 2227                       979
# 2232                       281
# 2233                       898
# 2243                       362
#
#                                               Exit Note reopen_date  \
# 5     **LEA county on the Transition page and demogr...  2020-04-06
# 8     02-11-2021 – PWN signed and returned for volun...  2021-02-05
# 12    04/01/2021- File closed business day prior to ...  2019-01-11
# 16    05/10/2021 TPC held then parents withdrew from...  2020-02-28
# 21    05/25/21- parent withdraw Reopened: 08/04/2020...  2020-08-04
# ...                                                 ...         ...
# 2223  The family ended TEIS services, and requested ...  2020-07-28
# 2227  The TPC was late due to LEA getting COVID and ...  2019-02-05
# 2232  TPC 10/19/2020 Reopened: 03/05/2020 Exit Date:...  2020-03-05
# 2233  TPC held and further assessments agreed to; PA...  2018-10-25
# 2243  TPC was late due to SC's inability to get a re...  2019-07-19
#
#      exit_date_adjusted
# 5            2019-11-26
# 8            2020-04-07
# 12           2018-06-17
# 16           2019-12-05
# 21           2020-03-09
# ...                 ...
# 2223         2020-04-26
# 2227         2018-10-23
# 2232         2019-09-17
# 2233         2018-05-24
# 2243         2019-06-25
#
# [1691 rows x 13 columns]

# %%
search['Adjusted_Count'] = search['reopen_date'] - search['exit_date_adjusted']
search.head()
# Out:
# <ipython-input-32-8ca1d13bf3b4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   search['Adjusted_Count'] = search['reopen_date'] - search['exit_date_adjusted']
#    POE  Child ID        DOB Notification Date Initial Eligibility Date  \
# 5   UC    473474 2017-11-05        2020-04-06               2020-04-24
# 8   GN    469243 2019-07-26        2019-09-04               2019-10-01
# 12  SE    436339 2018-04-05        2019-01-11               2019-01-31
# 16  ET    474102 2018-05-11        2020-02-27               2020-03-12
# 21  GN    476958 2018-10-17        2020-08-04               2020-08-18
#
#    Initial IFSP Date Latest IFSP Date  \
# 5         2020-05-06       2020-06-23
# 8         2019-10-02       2020-03-19
# 12        2019-02-13       2021-01-29
# 16        2020-04-09       2021-03-29
# 21        2020-08-24       2021-02-12
#
#                                 Exit Reason  Exit Date  \
# 5   618 - Part B eligibility not determined 2020-11-04
# 8                     618 - Parent withdraw 2021-02-11
# 12  618 - Part B eligibility not determined 2021-04-01
# 16  618 - Part B eligibility not determined 2021-05-10
# 21                    618 - Parent withdraw 2021-05-25
#
#     Days from I-IFSP to Exit  \
# 5                        182
# 8                        498
# 12                       778
# 16                       396
# 21                       274
#
#                                             Exit Note reopen_date  \
# 5   **LEA county on the Transition page and demogr...  2020-04-06
# 8   02-11-2021 – PWN signed and returned for volun...  2021-02-05
# 12  04/01/2021- File closed business day prior to ...  2019-01-11
# 16  05/10/2021 TPC held then parents withdrew from...  2020-02-28
# 21  05/25/21- parent withdraw Reopened: 08/04/2020...  2020-08-04
#
#    exit_date_adjusted Adjusted_Count
# 5          2019-11-26       132 days
# 8          2020-04-07       304 days
# 12         2018-06-17       208 days
# 16         2019-12-05        85 days
# 21         2020-03-09       148 days

# %%
for index, row in search.iterrows():
    if ((row['exit_date_adjusted'] > row['Initial IFSP Date']) and
        (row['exit_date_adjusted'] < row['Exit Date']) and
        (row['reopen_date'] > row['Initial IFSP Date']) and
        (row['reopen_date'] < row['Exit Date'])):
        diff_days = (row['reopen_date'] - row['exit_date_adjusted']).days
        search.at[index, 'diff_days'] = diff_days
    else:
        search.at[index, 'diff_days'] = np.nan
# Out:
# /Users/brentcleland/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1599: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# /Users/brentcleland/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
search.head()
# Out:
#    POE  Child ID        DOB Notification Date Initial Eligibility Date  \
# 5   UC    473474 2017-11-05        2020-04-06               2020-04-24
# 8   GN    469243 2019-07-26        2019-09-04               2019-10-01
# 12  SE    436339 2018-04-05        2019-01-11               2019-01-31
# 16  ET    474102 2018-05-11        2020-02-27               2020-03-12
# 21  GN    476958 2018-10-17        2020-08-04               2020-08-18
#
#    Initial IFSP Date Latest IFSP Date  \
# 5         2020-05-06       2020-06-23
# 8         2019-10-02       2020-03-19
# 12        2019-02-13       2021-01-29
# 16        2020-04-09       2021-03-29
# 21        2020-08-24       2021-02-12
#
#                                 Exit Reason  Exit Date  \
# 5   618 - Part B eligibility not determined 2020-11-04
# 8                     618 - Parent withdraw 2021-02-11
# 12  618 - Part B eligibility not determined 2021-04-01
# 16  618 - Part B eligibility not determined 2021-05-10
# 21                    618 - Parent withdraw 2021-05-25
#
#     Days from I-IFSP to Exit  \
# 5                        182
# 8                        498
# 12                       778
# 16                       396
# 21                       274
#
#                                             Exit Note reopen_date  \
# 5   **LEA county on the Transition page and demogr...  2020-04-06
# 8   02-11-2021 – PWN signed and returned for volun...  2021-02-05
# 12  04/01/2021- File closed business day prior to ...  2019-01-11
# 16  05/10/2021 TPC held then parents withdrew from...  2020-02-28
# 21  05/25/21- parent withdraw Reopened: 08/04/2020...  2020-08-04
#
#    exit_date_adjusted Adjusted_Count  diff_days
# 5          2019-11-26       132 days        NaN
# 8          2020-04-07       304 days      304.0
# 12         2018-06-17       208 days        NaN
# 16         2019-12-05        85 days        NaN
# 21         2020-03-09       148 days        NaN

# %%
search_filtered = search[search['diff_days'].notnull()]
search.head()
# Out:
#    POE  Child ID        DOB Notification Date Initial Eligibility Date  \
# 5   UC    473474 2017-11-05        2020-04-06               2020-04-24
# 8   GN    469243 2019-07-26        2019-09-04               2019-10-01
# 12  SE    436339 2018-04-05        2019-01-11               2019-01-31
# 16  ET    474102 2018-05-11        2020-02-27               2020-03-12
# 21  GN    476958 2018-10-17        2020-08-04               2020-08-18
#
#    Initial IFSP Date Latest IFSP Date  \
# 5         2020-05-06       2020-06-23
# 8         2019-10-02       2020-03-19
# 12        2019-02-13       2021-01-29
# 16        2020-04-09       2021-03-29
# 21        2020-08-24       2021-02-12
#
#                                 Exit Reason  Exit Date  \
# 5   618 - Part B eligibility not determined 2020-11-04
# 8                     618 - Parent withdraw 2021-02-11
# 12  618 - Part B eligibility not determined 2021-04-01
# 16  618 - Part B eligibility not determined 2021-05-10
# 21                    618 - Parent withdraw 2021-05-25
#
#     Days from I-IFSP to Exit  \
# 5                        182
# 8                        498
# 12                       778
# 16                       396
# 21                       274
#
#                                             Exit Note reopen_date  \
# 5   **LEA county on the Transition page and demogr...  2020-04-06
# 8   02-11-2021 – PWN signed and returned for volun...  2021-02-05
# 12  04/01/2021- File closed business day prior to ...  2019-01-11
# 16  05/10/2021 TPC held then parents withdrew from...  2020-02-28
# 21  05/25/21- parent withdraw Reopened: 08/04/2020...  2020-08-04
#
#    exit_date_adjusted Adjusted_Count  diff_days
# 5          2019-11-26       132 days        NaN
# 8          2020-04-07       304 days      304.0
# 12         2018-06-17       208 days        NaN
# 16         2019-12-05        85 days        NaN
# 21         2020-03-09       148 days        NaN

# %%
num_rows = search_filtered.shape[0]
num_rows
# Out:
# 534

# %%
search_filtered['Exit Note'].str.count('(Exit Date: \d+.\d+.\d+)')
search_filtered['Exit Note'].str.count('(Reopened: \d+.\d+.\d+)')
# Out:
# 8       1
# 22      4
# 30      2
# 44      2
# 59      2
#        ..
# 2195    2
# 2198    2
# 2223    1
# 2227    1
# 2233    1
# Name: Exit Note, Length: 534, dtype: int64

# %%
search['Exit_Count'] = search["Exit Note"].str.count('(Exit Date: \d+.\d+.\d+)')
search['Reopen_Count'] = search["Exit Note"].str.count('(Reopened: \d+.\d+.\d+)')
search.head()
#ddid_search['Exit Note'].str.count('(Reopened: \d+.\d+.\d+)')
# Out:
# <ipython-input-38-235235ac7032>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   search['Exit_Count'] = search["Exit Note"].str.count('(Exit Date: \d+.\d+.\d+)')
# <ipython-input-38-235235ac7032>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   search['Reopen_Count'] = search["Exit Note"].str.count('(Reopened: \d+.\d+.\d+)')
#    POE  Child ID        DOB Notification Date Initial Eligibility Date  \
# 5   UC    473474 2017-11-05        2020-04-06               2020-04-24
# 8   GN    469243 2019-07-26        2019-09-04               2019-10-01
# 12  SE    436339 2018-04-05        2019-01-11               2019-01-31
# 16  ET    474102 2018-05-11        2020-02-27               2020-03-12
# 21  GN    476958 2018-10-17        2020-08-04               2020-08-18
#
#    Initial IFSP Date Latest IFSP Date  \
# 5         2020-05-06       2020-06-23
# 8         2019-10-02       2020-03-19
# 12        2019-02-13       2021-01-29
# 16        2020-04-09       2021-03-29
# 21        2020-08-24       2021-02-12
#
#                                 Exit Reason  Exit Date  \
# 5   618 - Part B eligibility not determined 2020-11-04
# 8                     618 - Parent withdraw 2021-02-11
# 12  618 - Part B eligibility not determined 2021-04-01
# 16  618 - Part B eligibility not determined 2021-05-10
# 21                    618 - Parent withdraw 2021-05-25
#
#     Days from I-IFSP to Exit  \
# 5                        182
# 8                        498
# 12                       778
# 16                       396
# 21                       274
#
#                                             Exit Note reopen_date  \
# 5   **LEA county on the Transition page and demogr...  2020-04-06
# 8   02-11-2021 – PWN signed and returned for volun...  2021-02-05
# 12  04/01/2021- File closed business day prior to ...  2019-01-11
# 16  05/10/2021 TPC held then parents withdrew from...  2020-02-28
# 21  05/25/21- parent withdraw Reopened: 08/04/2020...  2020-08-04
#
#    exit_date_adjusted Adjusted_Count  diff_days  Exit_Count  Reopen_Count
# 5          2019-11-26       132 days        NaN           1             1
# 8          2020-04-07       304 days      304.0           1             1
# 12         2018-06-17       208 days        NaN           1             1
# 16         2019-12-05        85 days        NaN           1             1
# 21         2020-03-09       148 days        NaN           1             1

# %%
search_edit = search
search_edit.head(1)
# Out:
#   POE  Child ID        DOB Notification Date Initial Eligibility Date  \
# 5  UC    473474 2017-11-05        2020-04-06               2020-04-24
#
#   Initial IFSP Date Latest IFSP Date                              Exit Reason  \
# 5        2020-05-06       2020-06-23  618 - Part B eligibility not determined
#
#    Exit Date  Days from I-IFSP to Exit  \
# 5 2020-11-04                       182
#
#                                            Exit Note reopen_date  \
# 5  **LEA county on the Transition page and demogr...  2020-04-06
#
#   exit_date_adjusted Adjusted_Count  diff_days  Exit_Count  Reopen_Count
# 5         2019-11-26       132 days        NaN           1             1

# %%
search_edit['summed_counts'] = search_edit['Exit_Count'] + search_edit['Reopen_Count']
search_edit
# Out:
# <ipython-input-40-a749a7a4ab41>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   search_edit['summed_counts'] = search_edit['Exit_Count'] + search_edit['Reopen_Count']
#      POE  Child ID        DOB Notification Date Initial Eligibility Date  \
# 5     UC    473474 2017-11-05        2020-04-06               2020-04-24
# 8     GN    469243 2019-07-26        2019-09-04               2019-10-01
# 12    SE    436339 2018-04-05        2019-01-11               2019-01-31
# 16    ET    474102 2018-05-11        2020-02-27               2020-03-12
# 21    GN    476958 2018-10-17        2020-08-04               2020-08-18
# ...   ..       ...        ...               ...                      ...
# 2223  ET    469136 2017-10-24        2019-09-04               2019-10-03
# 2227  SC    432033 2017-12-30        2018-03-13               2018-04-24
# 2232  ET    469330 2018-02-18        2020-03-05               2020-05-07
# 2233  SE    428532 2017-07-13        2018-01-04               2018-01-16
# 2243  ET    463610 2017-08-09        2019-07-18               2019-07-29
#
#      Initial IFSP Date Latest IFSP Date  \
# 5           2020-05-06       2020-06-23
# 8           2019-10-02       2020-03-19
# 12          2019-02-13       2021-01-29
# 16          2020-04-09       2021-03-29
# 21          2020-08-24       2021-02-12
# ...                ...              ...
# 2223        2019-10-23       2020-10-01
# 2227        2018-04-25       2020-10-19
# 2232        2020-05-13       2020-12-01
# 2233        2018-01-26       2020-04-01
# 2243        2019-08-12       2020-05-12
#
#                                   Exit Reason  Exit Date  \
# 5     618 - Part B eligibility not determined 2020-11-04
# 8                       618 - Parent withdraw 2021-02-11
# 12    618 - Part B eligibility not determined 2021-04-01
# 16    618 - Part B eligibility not determined 2021-05-10
# 21                      618 - Parent withdraw 2021-05-25
# ...                                       ...        ...
# 2223  618 - Part B eligibility not determined 2020-10-23
# 2227                    618 - Part B eligible 2020-12-29
# 2232                    618 - Part B eligible 2021-02-18
# 2233  618 - Part B eligibility not determined 2020-07-12
# 2243   618 - Attempts to contact unsuccessful 2020-08-08
#
#       Days from I-IFSP to Exit  \
# 5                          182
# 8                          498
# 12                         778
# 16                         396
# 21                         274
# ...                        ...
# 2223                       366
# 2227                       979
# 2232                       281
# 2233                       898
# 2243                       362
#
#                                               Exit Note reopen_date  \
# 5     **LEA county on the Transition page and demogr...  2020-04-06
# 8     02-11-2021 – PWN signed and returned for volun...  2021-02-05
# 12    04/01/2021- File closed business day prior to ...  2019-01-11
# 16    05/10/2021 TPC held then parents withdrew from...  2020-02-28
# 21    05/25/21- parent withdraw Reopened: 08/04/2020...  2020-08-04
# ...                                                 ...         ...
# 2223  The family ended TEIS services, and requested ...  2020-07-28
# 2227  The TPC was late due to LEA getting COVID and ...  2019-02-05
# 2232  TPC 10/19/2020 Reopened: 03/05/2020 Exit Date:...  2020-03-05
# 2233  TPC held and further assessments agreed to; PA...  2018-10-25
# 2243  TPC was late due to SC's inability to get a re...  2019-07-19
#
#      exit_date_adjusted Adjusted_Count  diff_days  Exit_Count  Reopen_Count  \
# 5            2019-11-26       132 days        NaN           1             1
# 8            2020-04-07       304 days      304.0           1             1
# 12           2018-06-17       208 days        NaN           1             1
# 16           2019-12-05        85 days        NaN           1             1
# 21           2020-03-09       148 days        NaN           1             1
# ...                 ...            ...        ...         ...           ...
# 2223         2020-04-26        93 days       93.0           1             1
# 2227         2018-10-23       105 days      105.0           1             1
# 2232         2019-09-17       170 days        NaN           1             1
# 2233         2018-05-24       154 days      154.0           1             1
# 2243         2019-06-25        24 days        NaN           1             1
#
#       summed_counts
# 5                 2
# 8                 2
# 12                2
# 16                2
# 21                2
# ...             ...
# 2223              2
# 2227              2
# 2232              2
# 2233              2
# 2243              2
#
# [1691 rows x 18 columns]

# %%
newexit = pd.to_datetime(search_edit['Exit Note'].str.extractall('Exit Date: (\d+.\d+.\d+)')[0]).unstack()
newexit.columns = ['exit_' + str(col + 1) for col in newexit.columns]
newexit
# Out:
#          exit_1 exit_2 exit_3 exit_4 exit_5 exit_6 exit_7
# 5    2019-11-26    NaT    NaT    NaT    NaT    NaT    NaT
# 8    2020-04-07    NaT    NaT    NaT    NaT    NaT    NaT
# 12   2018-06-17    NaT    NaT    NaT    NaT    NaT    NaT
# 16   2019-12-05    NaT    NaT    NaT    NaT    NaT    NaT
# 21   2020-03-09    NaT    NaT    NaT    NaT    NaT    NaT
# ...         ...    ...    ...    ...    ...    ...    ...
# 2223 2020-04-26    NaT    NaT    NaT    NaT    NaT    NaT
# 2227 2018-10-23    NaT    NaT    NaT    NaT    NaT    NaT
# 2232 2019-09-17    NaT    NaT    NaT    NaT    NaT    NaT
# 2233 2018-05-24    NaT    NaT    NaT    NaT    NaT    NaT
# 2243 2019-06-25    NaT    NaT    NaT    NaT    NaT    NaT
#
# [1691 rows x 7 columns]

# %%
newenter = pd.to_datetime(search_edit['Exit Note'].str.extractall('Reopened: (\d+.\d+.\d+)')[0]).unstack()
newenter.columns = ['enter_' + str(col + 1) for col in newenter.columns]
newenter
# Out:
#         enter_1 enter_2 enter_3 enter_4 enter_5 enter_6
# 5    2020-04-06     NaT     NaT     NaT     NaT     NaT
# 8    2021-02-05     NaT     NaT     NaT     NaT     NaT
# 12   2019-01-11     NaT     NaT     NaT     NaT     NaT
# 16   2020-02-28     NaT     NaT     NaT     NaT     NaT
# 21   2020-08-04     NaT     NaT     NaT     NaT     NaT
# ...         ...     ...     ...     ...     ...     ...
# 2223 2020-07-28     NaT     NaT     NaT     NaT     NaT
# 2227 2019-02-05     NaT     NaT     NaT     NaT     NaT
# 2232 2020-03-05     NaT     NaT     NaT     NaT     NaT
# 2233 2018-10-25     NaT     NaT     NaT     NaT     NaT
# 2243 2019-07-19     NaT     NaT     NaT     NaT     NaT
#
# [1691 rows x 6 columns]

# %%
rentry_df = pd.merge(newexit, newenter, left_index=True, right_index=True)
#rentry_df.to_csv('re-enter.csv')

# %%
search_all = pd.merge(search_edit,  rentry_df,  left_index=True, right_index=True)

# %%
#search_all.to_csv('search_all.csv')

# %%
search_all.columns
# Out:
# Index(['POE', 'Child ID', 'DOB', 'Notification Date',
#        'Initial Eligibility Date', 'Initial IFSP Date', 'Latest IFSP Date',
#        'Exit Reason', 'Exit Date', 'Days from I-IFSP to Exit', 'Exit Note',
#        'reopen_date', 'exit_date_adjusted', 'Adjusted_Count', 'diff_days',
#        'Exit_Count', 'Reopen_Count', 'summed_counts', 'exit_1', 'exit_2',
#        'exit_3', 'exit_4', 'exit_5', 'exit_6', 'exit_7', 'enter_1', 'enter_2',
#        'enter_3', 'enter_4', 'enter_5', 'enter_6'],
#       dtype='object')

# %%
for index, row in search_all.iterrows():
    new_diff = 0
    for num in range(1,7):
        if ((row[f'exit_{num}'] != row[f'enter_{num}']) and
            (row[f'exit_{num}'] != np.nan)  and
            (row[f'enter_{num}'] != np.nan) and
            (row[f'exit_{num}'] > row['Initial IFSP Date']) and
            (row[f'exit_{num}'] < row['Exit Date']) and
            (row[f'enter_{num}'] > row['Initial IFSP Date']) and
            (row[f'enter_{num}'] < row['Exit Date'])):
            mult_diff_days = (row[f'enter_{num}'] - row[f'exit_{num}']).days
            new_diff += mult_diff_days
            search_all.at[index, 'diff_days_new'] = new_diff
        else:
            pass
#print(search_all.head(15))
#search_all.to_csv('search_all.csv')

# %%
#import pandas as pd

#df = {"A1":[15,25], "B1": [30, 40], "A2":[50,60], "B2": [70, 80]}
#df = pd.DataFrame(df)
#first_cols = ["A1", "B1"]
#second_cols = ["A2", "B2"]

#sub_cols = ["A_sub","B_sub"]

#df[sub_cols] = df[first_cols] - df[second_cols].values

# %%
search_all['new_calc_date'] = search_all['Days from I-IFSP to Exit'] + search_all['diff_days_new']
search_all
# Out:
#      POE  Child ID        DOB Notification Date Initial Eligibility Date  \
# 5     UC    473474 2017-11-05        2020-04-06               2020-04-24
# 8     GN    469243 2019-07-26        2019-09-04               2019-10-01
# 12    SE    436339 2018-04-05        2019-01-11               2019-01-31
# 16    ET    474102 2018-05-11        2020-02-27               2020-03-12
# 21    GN    476958 2018-10-17        2020-08-04               2020-08-18
# ...   ..       ...        ...               ...                      ...
# 2223  ET    469136 2017-10-24        2019-09-04               2019-10-03
# 2227  SC    432033 2017-12-30        2018-03-13               2018-04-24
# 2232  ET    469330 2018-02-18        2020-03-05               2020-05-07
# 2233  SE    428532 2017-07-13        2018-01-04               2018-01-16
# 2243  ET    463610 2017-08-09        2019-07-18               2019-07-29
#
#      Initial IFSP Date Latest IFSP Date  \
# 5           2020-05-06       2020-06-23
# 8           2019-10-02       2020-03-19
# 12          2019-02-13       2021-01-29
# 16          2020-04-09       2021-03-29
# 21          2020-08-24       2021-02-12
# ...                ...              ...
# 2223        2019-10-23       2020-10-01
# 2227        2018-04-25       2020-10-19
# 2232        2020-05-13       2020-12-01
# 2233        2018-01-26       2020-04-01
# 2243        2019-08-12       2020-05-12
#
#                                   Exit Reason  Exit Date  \
# 5     618 - Part B eligibility not determined 2020-11-04
# 8                       618 - Parent withdraw 2021-02-11
# 12    618 - Part B eligibility not determined 2021-04-01
# 16    618 - Part B eligibility not determined 2021-05-10
# 21                      618 - Parent withdraw 2021-05-25
# ...                                       ...        ...
# 2223  618 - Part B eligibility not determined 2020-10-23
# 2227                    618 - Part B eligible 2020-12-29
# 2232                    618 - Part B eligible 2021-02-18
# 2233  618 - Part B eligibility not determined 2020-07-12
# 2243   618 - Attempts to contact unsuccessful 2020-08-08
#
#       Days from I-IFSP to Exit  ... exit_6 exit_7    enter_1 enter_2  enter_3  \
# 5                          182  ...    NaT    NaT 2020-04-06     NaT      NaT
# 8                          498  ...    NaT    NaT 2021-02-05     NaT      NaT
# 12                         778  ...    NaT    NaT 2019-01-11     NaT      NaT
# 16                         396  ...    NaT    NaT 2020-02-28     NaT      NaT
# 21                         274  ...    NaT    NaT 2020-08-04     NaT      NaT
# ...                        ...  ...    ...    ...        ...     ...      ...
# 2223                       366  ...    NaT    NaT 2020-07-28     NaT      NaT
# 2227                       979  ...    NaT    NaT 2019-02-05     NaT      NaT
# 2232                       281  ...    NaT    NaT 2020-03-05     NaT      NaT
# 2233                       898  ...    NaT    NaT 2018-10-25     NaT      NaT
# 2243                       362  ...    NaT    NaT 2019-07-19     NaT      NaT
#
#       enter_4  enter_5  enter_6 diff_days_new new_calc_date
# 5         NaT      NaT      NaT           NaN           NaN
# 8         NaT      NaT      NaT         304.0         802.0
# 12        NaT      NaT      NaT           NaN           NaN
# 16        NaT      NaT      NaT           NaN           NaN
# 21        NaT      NaT      NaT           NaN           NaN
# ...       ...      ...      ...           ...           ...
# 2223      NaT      NaT      NaT          93.0         459.0
# 2227      NaT      NaT      NaT         105.0        1084.0
# 2232      NaT      NaT      NaT           NaN           NaN
# 2233      NaT      NaT      NaT         154.0        1052.0
# 2243      NaT      NaT      NaT           NaN           NaN
#
# [1691 rows x 33 columns]

# %%
search_all['Exit Note'].str.extract('(Exit Reason: )').unstack()
# Out:
# 0  5       Exit Reason:
#    8       Exit Reason:
#    12      Exit Reason:
#    16      Exit Reason:
#    21      Exit Reason:
#                ...
#    2223    Exit Reason:
#    2227    Exit Reason:
#    2232    Exit Reason:
#    2233    Exit Reason:
#    2243    Exit Reason:
# Length: 1691, dtype: object

# %%
#newexit = pd.to_datetime(search_edit['Exit Note'].str.extractall('Exit Reason: (\d+.\d+.\d+)')[0]).unstack()
#newexit.columns = ['exit_' + str(col + 1) for col in newexit.columns]
newexit
# Out:
#          exit_1 exit_2 exit_3 exit_4 exit_5 exit_6 exit_7
# 5    2019-11-26    NaT    NaT    NaT    NaT    NaT    NaT
# 8    2020-04-07    NaT    NaT    NaT    NaT    NaT    NaT
# 12   2018-06-17    NaT    NaT    NaT    NaT    NaT    NaT
# 16   2019-12-05    NaT    NaT    NaT    NaT    NaT    NaT
# 21   2020-03-09    NaT    NaT    NaT    NaT    NaT    NaT
# ...         ...    ...    ...    ...    ...    ...    ...
# 2223 2020-04-26    NaT    NaT    NaT    NaT    NaT    NaT
# 2227 2018-10-23    NaT    NaT    NaT    NaT    NaT    NaT
# 2232 2019-09-17    NaT    NaT    NaT    NaT    NaT    NaT
# 2233 2018-05-24    NaT    NaT    NaT    NaT    NaT    NaT
# 2243 2019-06-25    NaT    NaT    NaT    NaT    NaT    NaT
#
# [1691 rows x 7 columns]

# %%
c = ddid['Exit Note'].str.partition('(Exit Reason:)')[0]
c
# Out:
# 0                 * No Exit ECO available due to COVID-19
# 1       ***family moving out of state March 2021, and ...
# 2       **Completed the transition planning conference...
# 3       **Completed the transition planning conference...
# 4       **Due to the impact of the COVID-19 pandemic a...
#                               ...
# 5577                                                  NaN
# 5578                                                  NaN
# 5579                                                  NaN
# 5580                                                  NaN
# 5581                                                  NaN
# Name: 0, Length: 5582, dtype: object

# %% [markdown]
# pandas.pivot_table(data, values=None, index=None, columns=None, aggfunc='mean',
#                    fill_value=None, margins=False, dropna=True, margins_name='All',
#                    observed=False, sort=True)[source]

# %%
pd.pivot_table(search_all, values='new_calc_date', index=['POE'], columns=['Exit Reason'], aggfunc=np.sum)
# Out:
# Exit Reason  618 - Attempts to contact unsuccessful  \
# POE
# ET                                          12835.0
# FT                                          17246.0
# GN                                          17342.0
# MD                                          22669.0
# NW                                           5457.0
# SC                                           8804.0
# SE                                           9816.0
# SW                                          10326.0
# UC                                           5513.0
#
# Exit Reason  618 - Completion of IFSP/ no longer requires services  \
# POE
# ET                                                         0.0
# FT                                                         0.0
# GN                                                       638.0
# MD                                                      1765.0
# NW                                                         NaN
# SC                                                       655.0
# SE                                                         0.0
# SW                                                         NaN
# UC                                                       619.0
#
# Exit Reason  618 - Deceased  618 - Moved out of state  \
# POE
# ET                    695.0                    2017.0
# FT                      NaN                    1711.0
# GN                      NaN                    3736.0
# MD                    878.0                    2814.0
# NW                      NaN                     540.0
# SC                      0.0                       NaN
# SE                      NaN                       0.0
# SW                      NaN                       0.0
# UC                      0.0                       0.0
#
# Exit Reason  618 - Not eligible for Part B – Exit with no referrals  \
# POE
# ET                                                      6963.0
# FT                                                         0.0
# GN                                                         0.0
# MD                                                         0.0
# NW                                                         0.0
# SC                                                      3309.0
# SE                                                         0.0
# SW                                                         0.0
# UC                                                         0.0
#
# Exit Reason  618 - Not eligible for Part B – Exit with referral to other programs  \
# POE
# ET                                                      2282.0
# FT                                                      3064.0
# GN                                                      2181.0
# MD                                                       672.0
# NW                                                      2674.0
# SC                                                      2392.0
# SE                                                       787.0
# SW                                                         0.0
# UC                                                      1843.0
#
# Exit Reason  618 - Parent withdraw  618 - Part B eligibility not determined  \
# POE
# ET                         20468.0                                  20594.0
# FT                          5955.0                                  16141.0
# GN                         12063.0                                  24012.0
# MD                          7890.0                                  27908.0
# NW                         12834.0                                   7655.0
# SC                         11107.0                                  10203.0
# SE                          8635.0                                  11259.0
# SW                         15926.0                                  15633.0
# UC                         14134.0                                   9361.0
#
# Exit Reason  618 - Part B eligible
# POE
# ET                         12018.0
# FT                          7999.0
# GN                          6002.0
# MD                          2876.0
# NW                          6424.0
# SC                          6585.0
# SE                         11461.0
# SW                          7393.0
# UC                          9691.0

# %%
# read 2nd sheet of an excel file
eco = pd.read_excel(r"/Users/brentcleland/NSS/Projects/ddid-rasberry-pi/data/TEIS Exit Data for NSS.xlsx", sheet_name =2)

# %%
#print(eco.head())

# %%
pivot = pd.merge(search_all, eco, how='left', left_on='Child ID', right_on ='CHILD_ID')
#rentry_df.to_csv('re-enter.csv')

# %%
pivot
# Out:
#      POE Child ID      DOB_x Notification Date Initial Eligibility Date  \
# 0     UC   473474 2017-11-05        2020-04-06               2020-04-24
# 1     GN   469243 2019-07-26        2019-09-04               2019-10-01
# 2     SE   436339 2018-04-05        2019-01-11               2019-01-31
# 3     ET   474102 2018-05-11        2020-02-27               2020-03-12
# 4     GN   476958 2018-10-17        2020-08-04               2020-08-18
# ...   ..      ...        ...               ...                      ...
# 1686  ET   469136 2017-10-24        2019-09-04               2019-10-03
# 1687  SC   432033 2017-12-30        2018-03-13               2018-04-24
# 1688  ET   469330 2018-02-18        2020-03-05               2020-05-07
# 1689  SE   428532 2017-07-13        2018-01-04               2018-01-16
# 1690  ET   463610 2017-08-09        2019-07-18               2019-07-29
#
#      Initial IFSP Date_x Latest IFSP Date  \
# 0             2020-05-06       2020-06-23
# 1             2019-10-02       2020-03-19
# 2             2019-02-13       2021-01-29
# 3             2020-04-09       2021-03-29
# 4             2020-08-24       2021-02-12
# ...                  ...              ...
# 1686          2019-10-23       2020-10-01
# 1687          2018-04-25       2020-10-19
# 1688          2020-05-13       2020-12-01
# 1689          2018-01-26       2020-04-01
# 1690          2019-08-12       2020-05-12
#
#                                 Exit Reason_x Exit Date_x  \
# 0     618 - Part B eligibility not determined  2020-11-04
# 1                       618 - Parent withdraw  2021-02-11
# 2     618 - Part B eligibility not determined  2021-04-01
# 3     618 - Part B eligibility not determined  2021-05-10
# 4                       618 - Parent withdraw  2021-05-25
# ...                                       ...         ...
# 1686  618 - Part B eligibility not determined  2020-10-23
# 1687                    618 - Part B eligible  2020-12-29
# 1688                    618 - Part B eligible  2021-02-18
# 1689  618 - Part B eligibility not determined  2020-07-12
# 1690   618 - Attempts to contact unsuccessful  2020-08-08
#
#       Days from I-IFSP to Exit  ... OC2 - d OC2 - e OC2 Data Check OC3 - a  \
# 0                          182  ...     NaN     NaN            0.0     NaN
# 1                          498  ...     NaN     NaN            1.0     NaN
# 2                          778  ...     1.0     NaN            1.0     NaN
# 3                          396  ...     1.0     NaN            1.0     NaN
# 4                          274  ...     NaN     1.0            1.0     NaN
# ...                        ...  ...     ...     ...            ...     ...
# 1686                       366  ...     NaN     1.0            1.0     NaN
# 1687                       979  ...     NaN     NaN            1.0     NaN
# 1688                       281  ...     1.0     NaN            1.0     NaN
# 1689                       898  ...     NaN     NaN            1.0     NaN
# 1690                       362  ...     1.0     NaN            1.0     NaN
#
#       OC3 - b  OC3 - c  OC3 - d  OC3 - e OC3 Data Check  \
# 0         NaN      NaN      NaN      NaN            0.0
# 1         1.0      NaN      NaN      NaN            1.0
# 2         NaN      NaN      1.0      NaN            1.0
# 3         NaN      NaN      NaN      1.0            1.0
# 4         NaN      NaN      NaN      1.0            1.0
# ...       ...      ...      ...      ...            ...
# 1686      NaN      NaN      NaN      1.0            1.0
# 1687      NaN      NaN      1.0      NaN            1.0
# 1688      NaN      NaN      1.0      NaN            1.0
# 1689      1.0      NaN      NaN      NaN            1.0
# 1690      NaN      NaN      NaN      1.0            1.0
#
#      Days btw Initial and Exit
# 0                        182.0
# 1                        498.0
# 2                        778.0
# 3                        396.0
# 4                        274.0
# ...                        ...
# 1686                     366.0
# 1687                     979.0
# 1688                     280.0
# 1689                     898.0
# 1690                     362.0
#
# [1691 rows x 102 columns]

# %%
oc1 = pd.pivot_table(pivot, values='new_calc_date', index= ['POE'], columns=('OC1 - b' ),
                     aggfunc=np.mean, margins=sum)
oc1
# Out:
# OC1 - b          1.0          All
# POE
# ET        784.894737   784.894737
# FT       1058.500000  1058.500000
# GN        864.000000   864.000000
# MD        851.177778   851.177778
# NW        947.833333   947.833333
# SC        774.900000   774.900000
# SE       1112.714286  1112.714286
# SW        848.318182   848.318182
# UC        756.833333   756.833333
# All       865.474359   865.474359

# %%
oc2 = pd.pivot_table(pivot, values='new_calc_date', index= ['POE'], columns=('OC2 - b' ),
                     aggfunc=np.median, margins=sum)
oc2
# Out:
# OC2 - b     1.0     All
# POE
# ET        793.0   793.0
# FT       1050.5  1050.5
# GN        814.5   814.5
# MD        805.0   805.0
# NW       1091.0  1091.0
# SC        918.5   918.5
# SE       1069.5  1069.5
# SW        855.0   855.0
# UC        971.5   971.5
# All       878.0   878.0

# %%
oc3 = pd.pivot_table(pivot, values='new_calc_date', index= ['POE'], columns=('OC3 - b',
                                                                            ) ,aggfunc=np.mean, margins=sum)
oc3
# Out:
# OC3 - b          1.0          All
# POE
# ET        837.714286   837.714286
# FT        989.727273   989.727273
# GN        858.791667   858.791667
# MD        829.636364   829.636364
# NW       1287.000000  1287.000000
# SC        806.600000   806.600000
# SE       1064.200000  1064.200000
# SW        864.785714   864.785714
# UC        738.875000   738.875000
# All       868.936000   868.936000

# %%
oc1 = pd.pivot_table(pivot, values='new_calc_date', index= ['POE'], columns=('OC1 - d' ),aggfunc=np.mean, margins=sum)
oc2 = pd.pivot_table(pivot, values='new_calc_date', index= ['POE'], columns=('OC2 - d' ),aggfunc=np.mean, margins=sum)
oc3 = pd.pivot_table(pivot, values='new_calc_date', index= ['POE'], columns=('OC3 - d' ),aggfunc=np.mean, margins=sum)
#oc1.to_csv('oc1d.csv')
#oc2.to_csv('oc2d.csv')
#oc3.to_csv('oc3d.csv')

# %%
pd.pivot_table(search_all, values='new_calc_date', index= ['POE'],  
                     aggfunc=np.mean, margins=sum)
# Out:
#      new_calc_date
# POE
# ET      905.488372
# FT      898.551724
# GN      824.675000
# MD      812.915663
# NW      912.410256
# SC      916.063830
# SE      856.285714
# SW      929.773585
# UC      823.220000
# All     870.587156
